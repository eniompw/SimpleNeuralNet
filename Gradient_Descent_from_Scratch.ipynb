# %% [markdown]
# <a href="https://colab.research.google.com/github/eniompw/SimpleNeuralNet/blob/main/Gradient_Descent_from_Scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing Libraries
import numpy as np

# Data y = 2x + 50
x = np.arange(100)		# 200 causes an overflow in training
y = 2 * x + 50
# Add Gaussian noise to data
noise = np.random.normal(0, 5, 100)
y = y + noise

# Print first 10 values
print("x y")
for i in range(10):
	print(x[i] , y[i])
# Out:
# x y
# 0 42.34069234417484
# 1 59.91530961322162
# 2 48.419845836074856
# 3 71.12706222358821
# 4 58.36975369878608
# 5 65.32594886655875
# 6 55.36206771035209
# 7 67.63215479037288
# 8 67.02971866662175
# 9 67.37243370194845

# %%
# Draw all Data points
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.scatter(x,y)

# %%
# Draw all Data points
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.scatter(x,y)

weight = 0.1
bias = 0.01
y_pred = (weight * x) + bias
plt.plot(x,y_pred,'-r')

# %%
# Draw all Data points
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.scatter(x,y)

weight = 0.1
bias = 0.01
y_pred = (weight * x) + bias
plt.plot(x,y_pred,'-r')

dx = [x[50], x[50]]
dy = [y[50], y_pred[50]]
plt.plot(dx, dy, '-g')

# %%
def mean_squared_error(y, y_pred):
	# Calculating the loss or cost
	cost = np.sum((y - y_pred) ** 2) / len(y)
	return cost

# %%
learning_rate = 0.0001
costs = []

for i in range(50000):
  # Calculating the current cost
  current_cost = mean_squared_error(y, y_pred)
  costs.append(current_cost)

  # Calculating the gradients
  n = len(y)
  weight_derivative = -(2/n) * sum(x * (y - y_pred))
  bias_derivative = -(2/n) * sum(y - y_pred)

  # Updating weights and bias
  weight = weight - (learning_rate * weight_derivative)
  bias = bias - (learning_rate * bias_derivative)
  y_pred = (weight * x) + bias

print("weight:" , weight)
print("bias:" , bias)
# Out:
# weight: 2.049343970892593
# bias: 46.44739462426168

# %%
# Visualising the learning
plt.figure(figsize=(10,10))
plt.xlabel("Iterations")
plt.ylabel("Cost")
plt.plot(costs[10:])

# %%
# Final Model vs Data
plt.figure(figsize=(10,10))
plt.plot(x,y_pred,'-r')
plt.scatter(x,y)
